# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot') 
pd.set_option('display.max_columns', 200)

# %%
data = pd.read_csv("/Users/rahulprashamsivalingam/Downloads/coaster_db.csv")

# %%
data.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
data.shape
# Out:
# (1087, 56)

# %%
data.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
data.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
data.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
data.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
data[['coaster_name', 
      #'Length', 'Speed', 
      'Location', 'Status', #'Opening date','Type',
      'Manufacturer', 
      #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 
      #'Opened', 'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
      # 'year_introduced', 
      'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', #'height_value', 'height_unit', 
      'height_ft',
       'Inversions_clean', 'Gforce_clean']]
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
data.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
#data.drop(['Fastrack available'], axis = 1) # necessary to make sure it drops the column and check at the right place
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
data.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df = data[['coaster_name', 
      #'Length', 'Speed', 
      'Location', 'Status', #'Opening date','Type',
      'Manufacturer', 
      #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 
      #'Opened', 'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
      'year_introduced', 
      'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', #'height_value', 'height_unit', 
      'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
df = df.rename(columns = {'Location':'location',
          'Status':'status',
           'Manufacturer':'manufacturer',
           'Type_Main':'type_main',
           'Inversions_clean':'inversions_clean',
           'Gforce_clean':'force_clean'
          })

# %%
df = df.rename(columns = {'inversions_clean':'invesrions',
                         'force_clean':'gforce'})

# %%
df.head()
# Out:
#                              coaster_name                        location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     status            manufacturer  year_introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   type_main opening_date_clean  speed_mph  height_ft  invesrions  gforce
# ...

# %%
df.isna().sum()
# Out:
# coaster_name            0
# location                0
# status                213
# manufacturer           59
# year_introduced         0
# latitude              275
# longitude             275
# type_main               0
# opening_date_clean    250
# speed_mph             150
# height_ft             916
# invesrions              0
# gforce                725
# dtype: int64

# %%
df['status'].value_counts()
# Out:
# Operating                                                         668
# Removed                                                           137
# Closed                                                             24
# Under construction                                                 15
# In Production                                                      11
# Discontinued                                                        7
# Closed in 2021                                                      2
# SBNO December 2019                                                  2
# Chapter 7 bankruptcy; rides dismantled and sold; property sold      2
# Not Currently Operating                                             1
# closed for maintenance as of july 30 no reopening date known        1
# Temporarily Closed                                                  1
# SBNO (Standing But Not Operating)                                   1
# ...

# %%
df.isna().sum()
# Out:
# coaster_name            0
# location                0
# status                213
# manufacturer           59
# year_introduced         0
# latitude              275
# longitude             275
# type_main               0
# opening_date_clean    250
# speed_mph             150
# height_ft             916
# invesrions              0
# gforce                725
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [coaster_name, location, status, manufacturer, year_introduced, latitude, longitude, type_main, opening_date_clean, speed_mph, height_ft, invesrions, gforce]
# Index: []

# %%
df.loc[df.duplicated(subset = ['coaster_name'])]
# Out:
#                             coaster_name                   location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   status                                       manufacturer  \
# ...

# %%
df.duplicated(subset = ['coaster_name']).sum()
# Out:
# 97

# %%
df['coaster_name'].value_counts()
# Out:
# Batman: The Ride                       7
# Flight of the Hippogriff               4
# Big Thunder Mountain Railroad          4
# American Dreier Looping                4
# Lego Technic Test Track                4
#                                       ..
# Back at the Barnyard Hayride           1
# Cactus Coaster                         1
# Cannonball Express (roller coaster)    1
# Cannonball Run (roller coaster)        1
# Wonder Woman Flight of Courage         1
# Name: coaster_name, Length: 990, dtype: int64

# %%
df['coaster_name'].unique()
# Out:
# array(['Switchback Railway', 'Flip Flap Railway',
#        'Switchback Railway (Euclid Beach Park)',
#        'Loop the Loop (Coney Island)', "Loop the Loop (Young's Pier)",
#        'Cannon Coaster', 'Leap-The-Dips',
#        'Figure Eight (Euclid Beach Park)', 'Drop the Dip',
#        'Scenic Railway (Euclid Beach Park)',
#        'Loop the Loop (Olentangy Park)', 'Aero Dips',
#        'Backety-Back Scenic Railway', 'Racer (1910 roller coaster)',
#        'Derby Racer', 'The Great Scenic Railway', 'Zippin Pippin',
#        'Racing Coaster', 'Whirl Pool Dips',
#        'Green Dragon (Lake Compounce)', 'The Wild One (roller coaster)',
#        'Jack Rabbit (Clementon Park)', 'Jack Rabbit (Kennywood)',
#        'Jack Rabbit (Seabreeze)', 'Scenic Railway (roller coaster)',
#        'Roller Coaster (Lagoon)', 'Big Dipper (Blackpool Pleasure Beach)',
#        'Wild Cat (Hersheypark)', 'The Bobs (roller coaster)',
#        'Giant Dipper', 'Pippin (roller coaster)',
# ...

# %%
df.query('coaster_name == "Crystal Beach Cyclone"') # select * from table where coaster_name = ''
# Out:
#              coaster_name            location   status        manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     year_introduced  latitude  longitude type_main opening_date_clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     speed_mph  height_ft  invesrions  gforce
# 39       60.0        NaN           0     4.0
# 43       60.0        NaN           0     4.0

# %%
df.duplicated(subset = ['coaster_name','location','opening_date_clean' ]).sum()
# Out:
# 97

# %%
df = df.loc[~df.duplicated(subset = ['coaster_name','location','opening_date_clean'])].reset_index(drop=True)

# %%
df.shape
# Out:
# (990, 13)

# %%
df.loc[df.duplicated(subset = ['location'])]
# Out:
#                            coaster_name                        location  \
# 4          Loop the Loop (Young's Pier)                           Other
# 5                        Cannon Coaster                    Coney Island
# 7      Figure Eight (Euclid Beach Park)  Cleveland, Ohio, United States
# 8                          Drop the Dip                    Coney Island
# 9    Scenic Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# ..                                  ...                             ...
# 985        Ice Breaker (roller coaster)                SeaWorld Orlando
# 986               Leviathan (Sea World)                       Sea World
# 987           Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                             Tumbili                  Kings Dominion
# 989      Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
#                  status                 manufacturer  year_introduced  \
# ...

# %%
df['year_introduced'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
n = 5
ax = df['year_introduced'].value_counts().head(n).plot(kind = 'bar', title = f'Top {n} year introduction')
ax.set_xlabel("Year Introduced")
ax.set_ylabel("Number of Parks")
# Out:
# Text(0, 0.5, 'Number of Parks')

# %%
df.columns
# Out:
# Index(['coaster_name', 'location', 'status', 'manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'type_main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'invesrions', 'gforce'],
#       dtype='object')

# %%
ax1 = df['speed_mph'].plot(kind = 'hist',bins = 30, title = 'Coaster speed')
ax1.set_xlabel('Speed')
ax1.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
ax2 = df['speed_mph'].plot(kind = 'kde', title = 'Roller coaster speed')
ax2.set_xlabel('Speed')
ax2.set_ylabel('Frequency')
plt.show()

# %%
ax3 = df.plot(kind = 'scatter', x = 'speed_mph', y = 'height_ft', title = 'Height vs Speed Ratio')
plt.show()

# %%
sns.scatterplot(x = 'speed_mph', y = 'height_ft', data = df, hue = 'year_introduced')
# Out:
# <Axes: xlabel='speed_mph', ylabel='height_ft'>

# %%
df.columns
# Out:
# Index(['coaster_name', 'location', 'status', 'manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'type_main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'invesrions', 'gforce'],
#       dtype='object')

# %%
sns.pairplot(df, vars = ['year_introduced','speed_mph','height_ft','invesrions', 'gforce' ], hue = 'type_main')

# %%
df_corr = df[['year_introduced','speed_mph','height_ft','invesrions', 'gforce']].dropna().corr()

# %%
df_corr.head()
# Out:
#                  year_introduced  speed_mph  height_ft  invesrions    gforce
# year_introduced         1.000000   0.171978   0.135413   -0.209887  0.160247
# speed_mph               0.171978   1.000000   0.733999   -0.028705  0.607383
# height_ft               0.135413   0.733999   1.000000   -0.079736  0.466482
# invesrions             -0.209887  -0.028705  -0.079736    1.000000  0.275991
# gforce                  0.160247   0.607383   0.466482    0.275991  1.000000

# %%
sns.heatmap(df_corr, annot = True)
# Out:
# <Axes: >

# %%
ax = df.query('location !="Other"')\
.groupby('location')['speed_mph']\
.agg(['mean','count' ])\
.query('count >=10').sort_values('mean')['mean']\
.plot(kind = 'barh',figsize = (12,5), title = 'Average Coast speed by location')
